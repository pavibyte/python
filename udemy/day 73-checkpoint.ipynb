# %%
import pandas as pd
df =pd.read_csv(r"C:\Users\VICTUS\OneDrive\Desktop\QueryResults.csv")

# %%
df.count
# Out:
# <bound method DataFrame.count of                         m     TagName  Unnamed: 2
# 0     2008-07-01 00:00:00          c#           3
# 1     2008-08-01 00:00:00    assembly           8
# 2     2008-08-01 00:00:00  javascript         162
# 3     2008-08-01 00:00:00           c          85
# 4     2008-08-01 00:00:00      python         124
# ...                   ...         ...         ...
# 1986  2020-07-01 00:00:00           r        5694
# 1987  2020-07-01 00:00:00          go         743
# 1988  2020-07-01 00:00:00        ruby         775
# 1989  2020-07-01 00:00:00        perl         182
# 1990  2020-07-01 00:00:00       swift        3607
#
# [1991 rows x 3 columns]>

# %%
df.head
# Out:
# <bound method NDFrame.head of                         m     TagName  Unnamed: 2
# 0     2008-07-01 00:00:00          c#           3
# 1     2008-08-01 00:00:00    assembly           8
# 2     2008-08-01 00:00:00  javascript         162
# 3     2008-08-01 00:00:00           c          85
# 4     2008-08-01 00:00:00      python         124
# ...                   ...         ...         ...
# 1986  2020-07-01 00:00:00           r        5694
# 1987  2020-07-01 00:00:00          go         743
# 1988  2020-07-01 00:00:00        ruby         775
# 1989  2020-07-01 00:00:00        perl         182
# 1990  2020-07-01 00:00:00       swift        3607
#
# [1991 rows x 3 columns]>

# %%
df.tail
# Out:
# <bound method NDFrame.tail of                         m     TagName  Unnamed: 2
# 0     2008-07-01 00:00:00          c#           3
# 1     2008-08-01 00:00:00    assembly           8
# 2     2008-08-01 00:00:00  javascript         162
# 3     2008-08-01 00:00:00           c          85
# 4     2008-08-01 00:00:00      python         124
# ...                   ...         ...         ...
# 1986  2020-07-01 00:00:00           r        5694
# 1987  2020-07-01 00:00:00          go         743
# 1988  2020-07-01 00:00:00        ruby         775
# 1989  2020-07-01 00:00:00        perl         182
# 1990  2020-07-01 00:00:00       swift        3607
#
# [1991 rows x 3 columns]>

# %%
pd.read_csv(r"C:\Users\VICTUS\OneDrive\Desktop\QueryResults.csv",names=['DATE','TAG','POSTS'],header=0)
# Out:
#                      DATE         TAG  POSTS
# 0     2008-07-01 00:00:00          c#      3
# 1     2008-08-01 00:00:00    assembly      8
# 2     2008-08-01 00:00:00  javascript    162
# 3     2008-08-01 00:00:00           c     85
# 4     2008-08-01 00:00:00      python    124
# ...                   ...         ...    ...
# 1986  2020-07-01 00:00:00           r   5694
# 1987  2020-07-01 00:00:00          go    743
# 1988  2020-07-01 00:00:00        ruby    775
# 1989  2020-07-01 00:00:00        perl    182
# 1990  2020-07-01 00:00:00       swift   3607
#
# [1991 rows x 3 columns]

# %% [markdown]
# names are arguments that can change the column name and making the header to 0 allows us to substitute our own column name.

# %%
df.groupby('TagName').sum()
# Out:
#                                                             m  Unnamed: 2
# TagName
# assembly    2008-08-01 00:00:002008-09-01 00:00:002008-10-...       34852
# c           2008-08-01 00:00:002008-09-01 00:00:002008-10-...      336042
# c#          2008-07-01 00:00:002008-08-01 00:00:002008-09-...     1423530
# c++         2008-08-01 00:00:002008-09-01 00:00:002008-10-...      684210
# delphi      2008-08-01 00:00:002008-09-01 00:00:002008-10-...       46212
# go          2009-11-01 00:00:002009-12-01 00:00:002010-01-...       47499
# java        2008-08-01 00:00:002008-09-01 00:00:002008-10-...     1696403
# javascript  2008-08-01 00:00:002008-09-01 00:00:002008-10-...     2056510
# perl        2008-08-01 00:00:002008-09-01 00:00:002008-10-...       65286
# php         2008-08-01 00:00:002008-09-01 00:00:002008-10-...     1361988
# python      2008-08-01 00:00:002008-09-01 00:00:002008-10-...     1496210
# r           2008-09-01 00:00:002008-11-01 00:00:002008-12-...      356799
# ...

# %%
print(df.columns)
# Out:
# Index(['m', 'TagName', 'Unnamed: 2'], dtype='object')

# %%
df['m'][1]
# Out:
# '2008-08-01 00:00:00'

# %%
print(pd.to_datetime(df['m'][1]))
# Out:
# 2008-08-01 00:00:00

# %%
df.m = pd.to_datetime(df.m)

# %%
df.head()
# Out:
#            m     TagName  Unnamed: 2
# 0 2008-07-01          c#           3
# 1 2008-08-01    assembly           8
# 2 2008-08-01  javascript         162
# 3 2008-08-01           c          85
# 4 2008-08-01      python         124

# %%
reshaped_df = df.pivot(index='m',columns='TagName',values='Unnamed: 2')

# %%
import matplotlib.pyplot as plt

# %%
for column in reshaped_df.columns:
 plt.plot(reshaped_df.index,reshaped_df[column])
